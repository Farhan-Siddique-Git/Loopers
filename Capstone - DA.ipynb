# %%
import pandas as pd
import numpy as np
import matplotlib as plt
df1 = pd.read_csv('student_stress_dataset 1.csv')
df1
# Out:
#      Student_ID  Age  Gender  Sleep_Hours  Study_Hours  Physical_Activity  \
# 0             1   24  Female          6.6          8.4                 87
# 1             2   21  Female          6.4          7.9                 72
# 2             3   22    Male          3.2          6.2                 34
# 3             4   24  Female          5.4          9.6                 50
# 4             5   20  Female          5.7          2.8                 83
# ..          ...  ...     ...          ...          ...                ...
# 995         996   22  Female          6.4          2.9                 36
# 996         997   18  Female          7.0          8.8                 21
# 997         998   21  Female          9.1          9.0                 57
# 998         999   25    Male          9.9          2.8                 67
# 999        1000   20  Female          5.9          7.6                 92
#
#      Academic_Pressure  Financial_Stress  Social_Support
# ...

# %%
df2 = pd.read_csv('student_lifestyle_dataset 2.csv')
df2
# Out:
#       Student_ID  Study_Hours_Per_Day  Extracurricular_Hours_Per_Day  \
# 0              1                  6.9                            3.8
# 1              2                  5.3                            3.5
# 2              3                  5.1                            3.9
# 3              4                  6.5                            2.1
# 4              5                  8.1                            0.6
# ...          ...                  ...                            ...
# 1995        1996                  6.5                            0.2
# 1996        1997                  6.3                            2.8
# 1997        1998                  6.2                            0.0
# 1998        1999                  8.1                            0.7
# 1999        2000                  9.0                            1.7
#
#       Sleep_Hours_Per_Day  Social_Hours_Per_Day  \
# 0                     8.7                   2.8
# ...

# %%
df1.head()
# Out:
#    Student_ID  Age  Gender  Sleep_Hours  Study_Hours  Physical_Activity  \
# 0           1   24  Female          6.6          8.4                 87
# 1           2   21  Female          6.4          7.9                 72
# 2           3   22    Male          3.2          6.2                 34
# 3           4   24  Female          5.4          9.6                 50
# 4           5   20  Female          5.7          2.8                 83
#
#    Academic_Pressure  Financial_Stress  Social_Support
# 0                  2                 2               7
# 1                 10                 6               6
# 2                  9                 1               5
# 3                 10                 7               8
# 4                  7                 7               3

# %%
df2.head()
# Out:
#    Student_ID  Study_Hours_Per_Day  Extracurricular_Hours_Per_Day  \
# 0           1                  6.9                            3.8
# 1           2                  5.3                            3.5
# 2           3                  5.1                            3.9
# 3           4                  6.5                            2.1
# 4           5                  8.1                            0.6
#
#    Sleep_Hours_Per_Day  Social_Hours_Per_Day  Physical_Activity_Hours_Per_Day  \
# 0                  8.7                   2.8                              1.8
# 1                  8.0                   4.2                              3.0
# 2                  9.2                   1.2                              4.6
# 3                  7.2                   1.7                              6.5
# 4                  6.5                   2.2                              6.6
#
#     GPA Stress_Level
# 0  2.99     Moderate
# 1  2.75          Low
# 2  2.67          Low
# ...

# %%
df1.tail()
# Out:
#      Student_ID  Age  Gender  Sleep_Hours  Study_Hours  Physical_Activity  \
# 995         996   22  Female          6.4          2.9                 36
# 996         997   18  Female          7.0          8.8                 21
# 997         998   21  Female          9.1          9.0                 57
# 998         999   25    Male          9.9          2.8                 67
# 999        1000   20  Female          5.9          7.6                 92
#
#      Academic_Pressure  Financial_Stress  Social_Support
# 995                  6                 9               7
# 996                  5                 8              10
# 997                 10                 8               1
# 998                  6                 1               2
# 999                  3                 5               4

# %%
df2.tail()
# Out:
#       Student_ID  Study_Hours_Per_Day  Extracurricular_Hours_Per_Day  \
# 1995        1996                  6.5                            0.2
# 1996        1997                  6.3                            2.8
# 1997        1998                  6.2                            0.0
# 1998        1999                  8.1                            0.7
# 1999        2000                  9.0                            1.7
#
#       Sleep_Hours_Per_Day  Social_Hours_Per_Day  \
# 1995                  7.4                   2.1
# 1996                  8.8                   1.5
# 1997                  6.2                   0.8
# 1998                  7.6                   3.5
# 1999                  7.3                   3.1
#
#       Physical_Activity_Hours_Per_Day   GPA Stress_Level
# 1995                              7.8  3.32     Moderate
# 1996                              4.6  2.65     Moderate
# 1997                             10.8  3.14     Moderate
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Student_ID         1000 non-null   int64
#  1   Age                1000 non-null   int64
#  2   Gender             1000 non-null   object
#  3   Sleep_Hours        1000 non-null   float64
#  4   Study_Hours        1000 non-null   float64
#  5   Physical_Activity  1000 non-null   int64
#  6   Academic_Pressure  1000 non-null   int64
#  7   Financial_Stress   1000 non-null   int64
#  8   Social_Support     1000 non-null   int64
# dtypes: float64(2), int64(6), object(1)
# memory usage: 70.4+ KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 8 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Student_ID                       2000 non-null   int64
#  1   Study_Hours_Per_Day              2000 non-null   float64
#  2   Extracurricular_Hours_Per_Day    2000 non-null   float64
#  3   Sleep_Hours_Per_Day              2000 non-null   float64
#  4   Social_Hours_Per_Day             2000 non-null   float64
#  5   Physical_Activity_Hours_Per_Day  2000 non-null   float64
#  6   GPA                              2000 non-null   float64
#  7   Stress_Level                     2000 non-null   object
# dtypes: float64(6), int64(1), object(1)
# memory usage: 125.1+ KB

# %%
df1.describe()
# Out:
#         Student_ID        Age  Sleep_Hours  Study_Hours  Physical_Activity  \
# count  1000.000000  1000.0000   1000.00000  1000.000000        1000.000000
# mean    500.500000    21.4980      6.48820     5.512100          61.631000
# std     288.819436     2.3081      2.00375     2.603294          35.289463
# min       1.000000    18.0000      3.00000     1.000000           0.000000
# 25%     250.750000    19.7500      4.80000     3.300000          31.000000
# 50%     500.500000    21.0000      6.50000     5.600000          62.000000
# 75%     750.250000    24.0000      8.20000     7.700000          93.000000
# max    1000.000000    25.0000     10.00000    10.000000         120.000000
#
#        Academic_Pressure  Financial_Stress  Social_Support
# count        1000.000000       1000.000000       1000.0000
# mean            5.513000          5.562000          5.5600
# std             2.850255          2.908714          2.9146
# ...

# %%
df2.describe()
# Out:
#         Student_ID  Study_Hours_Per_Day  Extracurricular_Hours_Per_Day  \
# count  2000.000000          2000.000000                    2000.000000
# mean   1000.500000             7.475800                       1.990100
# std     577.494589             1.423888                       1.155855
# min       1.000000             5.000000                       0.000000
# 25%     500.750000             6.300000                       1.000000
# 50%    1000.500000             7.400000                       2.000000
# 75%    1500.250000             8.700000                       3.000000
# max    2000.000000            10.000000                       4.000000
#
#        Sleep_Hours_Per_Day  Social_Hours_Per_Day  \
# count          2000.000000           2000.000000
# mean              7.501250              2.704550
# std               1.460949              1.688514
# min               5.000000              0.000000
# 25%               6.200000              1.200000
# ...

# %%
df1.isna().sum()  #to check for null values
# Out:
# Student_ID           0
# Age                  0
# Gender               0
# Sleep_Hours          0
# Study_Hours          0
# Physical_Activity    0
# Academic_Pressure    0
# Financial_Stress     0
# Social_Support       0
# dtype: int64

# %%
df2.isna().sum()  #to check for null values
# Out:
# Student_ID                         0
# Study_Hours_Per_Day                0
# Extracurricular_Hours_Per_Day      0
# Sleep_Hours_Per_Day                0
# Social_Hours_Per_Day               0
# Physical_Activity_Hours_Per_Day    0
# GPA                                0
# Stress_Level                       0
# dtype: int64

# %%
df2['Stress_Level'].unique()
# Out:
# array(['Moderate', 'Low', 'High'], dtype=object)

# %%
df = pd.merge(
    left=df1,
    right=df2,
    on='Student_ID',  # Use this if the column name is the SAME in both DataFrames
    how='inner'       # Specifies the type of join
)

print(merged_df.head())
# Out:
#    Student_ID  Age  Gender  Sleep_Hours  Study_Hours  Physical_Activity  \
# 0           1   24  Female          6.6          8.4                 87
# 1           2   21  Female          6.4          7.9                 72
# 2           3   22    Male          3.2          6.2                 34
# 3           4   24  Female          5.4          9.6                 50
# 4           5   20  Female          5.7          2.8                 83
#
#    Academic_Pressure  Financial_Stress  Social_Support  Study_Hours_Per_Day  \
# 0                  2                 2               7                  6.9
# 1                 10                 6               6                  5.3
# 2                  9                 1               5                  5.1
# 3                 10                 7               8                  6.5
# 4                  7                 7               3                  8.1
#
# ...

# %%
df.drop(
    ['Physical_Activity', 'Physical_Activity_Hours_Per_Day'],
    axis=1,            # Tells Pandas to look for the labels in the columns (vertical axis)
    inplace=True
)

# %%
df.describe()
# Out:
#         Student_ID        Age  Sleep_Hours  Study_Hours  Academic_Pressure  \
# count  1000.000000  1000.0000   1000.00000  1000.000000        1000.000000
# mean    500.500000    21.4980      6.48820     5.512100           5.513000
# std     288.819436     2.3081      2.00375     2.603294           2.850255
# min       1.000000    18.0000      3.00000     1.000000           1.000000
# 25%     250.750000    19.7500      4.80000     3.300000           3.000000
# 50%     500.500000    21.0000      6.50000     5.600000           6.000000
# 75%     750.250000    24.0000      8.20000     7.700000           8.000000
# max    1000.000000    25.0000     10.00000    10.000000          10.000000
#
#        Financial_Stress  Social_Support  Study_Hours_Per_Day  \
# count       1000.000000       1000.0000          1000.000000
# mean           5.562000          5.5600             7.461300
# std            2.908714          2.9146             1.457201
# ...

# %%
stress_mapping = {'Low': 0, 'Moderate': 1, 'High': 2}
df['Stress_Numeric'] = df['Stress_Level'].map(stress_mapping)

print("Created 'Stress_Numeric' column for analysis.")
# Out:
# Created 'Stress_Numeric' column for analysis.

# %%
stress_mapping = {'Low': 0, 'Moderate': 1, 'High': 2}
df['Stress_Numeric'] = df['Stress_Level'].map(stress_mapping)

print("Created 'Stress_Numeric' column for analysis.")
# Out:
# Created 'Stress_Numeric' column for analysis.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(8, 5))
# Use the original categorical Stress_Level column for the box plot
sns.boxplot(x='Stress_Level', y='Sleep_Hours_Per_Day', data=df, order=['Low', 'Moderate', 'High'])
plt.title('Sleep Hours Distribution by Stress Level')
plt.xlabel('Stress Level')
plt.ylabel('Sleep Hours Per Day')
plt.show()
