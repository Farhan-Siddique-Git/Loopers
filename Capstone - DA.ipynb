# %%
import pandas as pd
import numpy as np
df1 = pd.read_csv('student_stress_dataset 1.csv')
df1
# Out:
#      Student_ID  Age  Gender  Sleep_Hours  Study_Hours  Physical_Activity  \
# 0             1   24  Female          6.6          8.4                 87
# 1             2   21  Female          6.4          7.9                 72
# 2             3   22    Male          3.2          6.2                 34
# 3             4   24  Female          5.4          9.6                 50
# 4             5   20  Female          5.7          2.8                 83
# ..          ...  ...     ...          ...          ...                ...
# 995         996   22  Female          6.4          2.9                 36
# 996         997   18  Female          7.0          8.8                 21
# 997         998   21  Female          9.1          9.0                 57
# 998         999   25    Male          9.9          2.8                 67
# 999        1000   20  Female          5.9          7.6                 92
#
#      Academic_Pressure  Financial_Stress  Social_Support
# ...

# %%
df2 = pd.read_csv('student_lifestyle_dataset 2.csv')
df2
# Out:
#       Student_ID  Study_Hours_Per_Day  Extracurricular_Hours_Per_Day  \
# 0              1                  6.9                            3.8
# 1              2                  5.3                            3.5
# 2              3                  5.1                            3.9
# 3              4                  6.5                            2.1
# 4              5                  8.1                            0.6
# ...          ...                  ...                            ...
# 1995        1996                  6.5                            0.2
# 1996        1997                  6.3                            2.8
# 1997        1998                  6.2                            0.0
# 1998        1999                  8.1                            0.7
# 1999        2000                  9.0                            1.7
#
#       Sleep_Hours_Per_Day  Social_Hours_Per_Day  \
# 0                     8.7                   2.8
# ...
